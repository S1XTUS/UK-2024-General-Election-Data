# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
base_link='https://election.news.sky.com/elections/general-election-2024/'

# %%
def json_to_dataframe(data, i):
    json_data=data['props']['pageProps']['fallbackData']['votingArea']['nominations']
    # Normalize JSON data into a DataFrame
    df = pd.json_normalize(json_data, sep='_')
    
    # Extract values and assign to DataFrame columns
    df['constituency'] = data['props']['pageProps']['components']['analytics']['name']
    df['party_name'] = df['party_name'].str.replace('\r\n', '')
    df['Electorate_size'] = data['props']['pageProps']['fallbackData']['votingArea']['electorate']
    df['Turnout_perc'] = data['props']['pageProps']['fallbackData']['votingArea']['turnoutPercentage']
    df['new_party'] = data['props']['pageProps']['fallbackData']['votingArea']['electedCandidate']['party']['name']
    df['old_party'] = data['props']['pageProps']['fallbackData']['votingArea']['previouslyElectedCandidate']['party']['name']
    df['index'] = i

    return df

# %%
columns = ['voteCount', 'votePercentage', 'votePercentageChange',
           'candidate_firstName', 'candidate_surname', 'party_abbreviation',
           'party_name', 'party_displayName', 'constituency', 'Electorate_size',
           'Turnout_perc', 'new_party', 'old_party', 'index']

df = pd.DataFrame(columns=columns)

# %%
for i in range(1, 651):
    url = base_link + str(i)

    response = requests.get(url)

    if response.status_code == 200:
        html_content = response.content
        
        soup = BeautifulSoup(html_content, 'html.parser')
        
        script_tag = soup.find('script', id='__NEXT_DATA__')
        
        if script_tag:
            json_data = script_tag.string
            
            data_dict = json.loads(json_data)
            
            temp = json_to_dataframe(data_dict, i)
            
            df = pd.merge(df, temp, how='outer')
        else:
            print(f"Script tag with id='__NEXT_DATA__' not found on {url}")
    else:
        print(f"Failed to retrieve data from URL: {url}. Status code: {response.status_code}")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4515 entries, 0 to 4514
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   voteCount             4515 non-null   int64
#  1   votePercentage        4515 non-null   float64
#  2   votePercentageChange  4515 non-null   float64
#  3   candidate_firstName   4515 non-null   object
#  4   candidate_surname     4515 non-null   object
#  5   party_abbreviation    4515 non-null   object
#  6   party_name            4515 non-null   object
#  7   party_displayName     4515 non-null   object
#  8   constituency          4515 non-null   object
#  9   Electorate_size       4515 non-null   int64
#  10  Turnout_perc          4515 non-null   float64
#  11  new_party             4515 non-null   object
#  12  old_party             4515 non-null   object
#  13  index                 4515 non-null   int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 494.0+ KB

# %%
df['constituency'].unique()
# Out:
# array(['Aberafan Maesteg', 'Aberdeen North', 'Aberdeen South',
#        'Aberdeenshire N & Moray E', 'Aberdeenshire W & Kincardine',
#        'Airdrie & Shotts', 'Aldershot', 'Aldridge-Brownhills',
#        'Alloa & Grangemouth', 'Altrincham & Sale West',
#        'Alyn and Deeside', 'Amber Valley', 'Angus & Perthshire Glens',
#        'Antrim East', 'Antrim North', 'Antrim South',
#        'Arbroath & Broughty Ferry', 'Argyll, Bute & S Lochaber',
#        'Arundel & South Downs', 'Ashfield', 'Ashford',
#        'Ashton-under-Lyne', 'Aylesbury', 'Ayr, Carrick & Cumnock',
#        'Ayrshire Central', 'Ayrshire North & Arran', 'Banbury',
#        'Bangor Aberconwy', 'Barking', 'Barnsley North', 'Barnsley South',
#        'Barrow & Furness', 'Basildon & Billericay',
#        'Basildon South & E Thurrock', 'Basingstoke', 'Bassetlaw', 'Bath',
#        'Bathgate & Linlithgow', 'Battersea', 'Beaconsfield',
#        'Beckenham & Penge', 'Bedford', 'Bedfordshire Mid',
#        'Bedfordshire North', 'Belfast East', 'Belfast North',
#        'Belfast South & Mid Down', 'Belfast West',
#        'Bermondsey & Old Southwark', 'Berwick, Roxburgh & Selkirk',
#        'Bethnal Green & Stepney', 'Beverley & Holderness',
#        'Bexhill & Battle', 'Bexleyheath & Crayford',
#        'Bicester & Woodstock', 'Birkenhead', 'Birmingham Edgbaston',
#        'Birmingham Erdington', "B'ham Hall Green & Moseley",
#        "B'ham Hodge Hill & S'hull N", 'Birmingham Ladywood',
#        'Birmingham Northfield', 'Birmingham Perry Barr',
#        'Birmingham Selly Oak', 'Birmingham Yardley', 'Bishop Auckland',
#        'Blackburn', 'Blackley & Middleton South',
#        'Blackpool North & Fleetwood', 'Blackpool South',
#        'Blaenau Gwent & Rhymney', 'Blaydon & Consett',
#        'Blyth & Ashington', 'Bognor Regis & Littlehampton', 'Bolsover',
#        'Bolton North East', 'Bolton South & Walkden', 'Bolton West',
#        'Bootle', 'Boston & Skegness', 'Bournemouth East',
#        'Bournemouth West', 'Bracknell', 'Bradford East', 'Bradford South',
#        'Bradford West', 'Braintree', 'Brecon, Radnor & Cwm Tawe',
#        'Brent East', 'Brent West', 'Brentford & Isleworth',
#        'Brentwood & Ongar', 'Bridgend', 'Bridgwater',
#        'Bridlington & the Wolds', 'Brigg & Immingham',
#        "Brighton Kemptown & P'haven", 'Brighton Pavilion',
#        'Bristol Central', 'Bristol East', 'Bristol North East',
#        'Bristol North West', 'Bristol South', 'Broadland & Fakenham',
#        'Bromley & Biggin Hill', 'Bromsgrove', 'Broxbourne', 'Broxtowe',
#        'Buckingham & Bletchley', 'Buckinghamshire Mid', 'Burnley',
#        'Burton & Uttoxeter', 'Bury North', 'Bury South',
#        'Bury St Edmunds & Stowmarket', 'Caerfyrddin', 'Caerphilly',
#        'Caith, Suther & Easter Ross', 'Calder Valley',
#        'Camborne & Redruth', 'Cambridge', 'Cambridgeshire North East',
#        'Cambridgeshire North West', 'Cambridgeshire South',
#        'Cannock Chase', 'Canterbury', 'Cardiff East', 'Cardiff North',
#        'Cardiff South & Penarth', 'Cardiff West', 'Carlisle',
#        'Carshalton & Wallington', 'Castle Point', 'Ceredigion Preseli',
#        'Chatham & Aylesford', 'Cheadle', 'Chelmsford', 'Chelsea & Fulham',
#        'Cheltenham', 'Chesham & Amersham', 'Cheshire Mid',
#        'Chester North & Neston', 'Chester South & Eddisbury',
#        'Chesterfield', 'Chichester', 'Chingford & Woodford Green',
#        'Chippenham', 'Chipping Barnet', 'Chorley', 'Christchurch',
#        "Cities of London & W'minster", 'Clacton',
#        'Clapham & Brixton Hill', 'Clwyd East', 'Clwyd North',
#        'Coatbridge & Bellshill', 'Colchester', 'Colne Valley',
#        'Congleton', 'Corby & East Northants', 'Cornwall North',
#        'Cornwall South East', 'Cotswolds North', 'Cotswolds South',
#        'Coventry East', 'Coventry North West', 'Coventry South',
#        'Cowdenbeath & Kirkcaldy', 'Cramlington & Killingworth', 'Crawley',
#        'Crewe & Nantwich', 'Croydon East', 'Croydon South',
#        'Croydon West', 'Cumbernauld & Kirkintilloch',
#        'Dagenham & Rainham', 'Darlington', 'Dartford', 'Daventry',
#        'Derby North', 'Derby South', 'Derbyshire Dales', 'Derbyshire Mid',
#        'Derbyshire North East', 'Derbyshire South', 'Devon Central',
#        'Devon North', 'Devon South', 'Devon South West',
#        'Dewsbury & Batley', 'Didcot & Wantage', 'Doncaster Central',
#        'Doncaster East & Axholme', 'Doncaster North', 'Dorking & Horley',
#        'Dorset Mid & North Poole', 'Dorset North', 'Dorset South',
#        'Dorset West', 'Dover & Deal', 'Droitwich & Evesham', 'Dudley',
#        'Dulwich & West Norwood', 'Dumfries & Galloway',
#        "Dumfries Clydesdale & T'dale", 'Dunbartonshire Mid',
#        'Dunbartonshire West', 'Dundee Central', 'Dunfermline & Dollar',
#        'Dunstable & Leighton Buzzard', 'Durham, City of', 'Durham North',
#        'Dwyfor Meirionnydd', 'Ealing Central & Acton', 'Ealing North',
#        'Ealing Southall', 'Earley & Woodley', 'Easington',
#        'East Grinstead & Uckfield', 'East Ham',
#        'East Kilbride & Strathaven', 'Eastbourne', 'Eastleigh',
#        'Edinburgh East & Musselburgh', 'Edinburgh North & Leith',
#        'Edinburgh South', 'Edinburgh South West', 'Edinburgh West',
#        'Edmonton & Winchmore Hill', 'Ellesmere Port & Bromborough',
#        'Eltham & Chislehurst', 'Ely & East Cambridgeshire',
#        'Enfield North', 'Epping Forest', 'Epsom & Ewell', 'Erewash',
#        'Erith & Thamesmead', 'Esher & Walton', 'Essex North West',
#        'Exeter', 'Exmouth & Exeter East', 'Falkirk',
#        'Fareham & Waterlooville', 'Farnham & Bordon',
#        'Faversham & Mid Kent', 'Feltham & Heston',
#        'Fermanagh & South Tyrone', 'Fife North East',
#        'Filton & Bradley Stoke', 'Finchley & Golders Green',
#        'Folkestone & Hythe', 'Forest of Dean', 'Foyle',
#        'Frome & East Somerset', 'Fylde', 'Gainsborough',
#        'Gateshead Central & Whickham', 'Gedling', 'Gillingham & Rainham',
#        'Glasgow East', 'Glasgow North', 'Glasgow North East',
#        'Glasgow South', 'Glasgow South West', 'Glasgow West',
#        'Glastonbury & Somerton', 'Glenrothes & Mid Fife', 'Gloucester',
#        'Godalming & Ash', 'Goole & Pocklington', 'Gordon & Buchan',
#        'Gorton & Denton', 'Gosport', 'Gower', 'Grantham & Bourne',
#        'Gravesham', 'Great Grimsby & Cleethorpes', 'Great Yarmouth',
#        'Greenwich & Woolwich', 'Guildford', 'Hackney N & Stoke Newington',
#        'Hackney South & Shoreditch', 'Halesowen', 'Halifax',
#        'Hamble Valley', 'Hamilton & Clyde Valley',
#        'Hammersmith & Chiswick', 'Hampshire East', 'Hampshire North East',
#        'Hampshire North West', 'Hampstead & Highgate',
#        'Harborough, Oadby & Wigston', 'Harlow', 'Harpenden & Berkhamsted',
#        'Harrogate & Knaresborough', 'Harrow East', 'Harrow West',
#        'Hartlepool', 'Harwich & North Essex', 'Hastings & Rye', 'Havant',
#        'Hayes & Harlington', 'Hazel Grove', 'Hemel Hempstead', 'Hendon',
#        'Henley & Thame', 'Hereford & S Herefordshire',
#        'Herefordshire North', 'Herne Bay & Sandwich',
#        'Hertford & Stortford', 'Hertfordshire North East',
#        'Hertfordshire South West', 'Hertsmere', 'Hexham',
#        'Heywood & Middleton North', 'High Peak', 'Hinckley & Bosworth',
#        'Hitchin', 'Holborn & St Pancras', 'Honiton & Sidmouth',
#        'Hornchurch & Upminster', 'Hornsey & Friern Barnet', 'Horsham',
#        'Houghton & Sunderland South', 'Hove & Portslade', 'Huddersfield',
#        'Hull East', 'Hull North & Cottingham', 'Hull West & Haltemprice',
#        'Huntingdon', 'Hyndburn', 'Ilford North', 'Ilford South',
#        'Inverclyde & Renfrewshire W', 'Inverness, Skye & West Ross',
#        'Ipswich', 'Isle of Wight East', 'Isle of Wight West',
#        'Islington North', 'Islington South & Finsbury',
#        'Jarrow & Gateshead East', 'Keighley & Ilkley',
#        'Kenilworth & Southam', 'Kensington & Bayswater', 'Kettering',
#        'Kilmarnock & Loudoun', 'Kingston & Surbiton',
#        'Kingswinford & Staffs South', 'Knowsley', 'Lagan Valley',
#        'Lancashire West', 'Lancaster & Wyre',
#        'Leeds Central & Headingley', 'Leeds East', 'Leeds North East',
#        'Leeds North West', 'Leeds South', 'Leeds South West & Morley',
#        'Leeds West & Pudsey', 'Leicester East', 'Leicester South',
#        'Leicester West', 'Leicestershire Mid',
#        'Leicestershire North West', 'Leicestershire South',
#        'Leigh & Atherton', 'Lewes', 'Lewisham East', 'Lewisham North',
#        'Lewisham West & East Dulwich', 'Leyton & Wanstead', 'Lichfield',
#        'Lincoln', 'Liverpool Garston', 'Liverpool Riverside',
#        'Liverpool Walton', 'Liverpool Wavertree', 'Liverpool West Derby',
#        'Livingston', 'Llanelli', 'Londonderry East', 'Lothian East',
#        'Loughborough', 'Louth & Horncastle', 'Lowestoft', 'Luton North',
#        'Luton South & South Bedfordshire', 'Macclesfield', 'Maidenhead',
#        'Maidstone & Malling', 'Makerfield', 'Maldon',
#        'Manchester Central', 'Manchester Rusholme',
#        'Manchester Withington', 'Mansfield', 'Melksham & Devizes',
#        'Melton & Syston', 'Meriden & Solihull East',
#        'Merthyr Tydfil & Aberdare', 'Middlesbrough & Thornaby E',
#        'Middlesbrough S & E Cleve.', 'Midlothian',
#        'Milton Keynes Central', 'Milton Keynes North', 'Mitcham & Morden',
#        'Monmouthshire', 'Montgomeryshire & Glyndwr',
#        'Moray W, Nairn & Strathspey', 'Morecambe & Lunesdale',
#        'Motherwell, Wishaw & Carluke', 'Western Isles',
#        'Neath & Swansea East', 'New Forest East', 'New Forest West',
#        'Newark', 'Newbury', 'Newcastle-under-Lyme',
#        'Newcastle Central & West', 'Newcastle East & Wallsend',
#        'Newcastle North', 'Newport East', 'Newport West & Islwyn',
#        'Newry & Armagh', 'Newton Abbot', 'Newton Aycliffe & Spennymoor',
#        'Norfolk Mid', 'Norfolk North', 'Norfolk North West',
#        'Norfolk South', 'Norfolk South West', 'Normanton & Hemsworth',
#        'North Down', 'Northampton North', 'Northampton South',
#        'Northamptonshire South', 'Northumberland North', 'Norwich North',
#        'Norwich South', 'Nottingham East', 'Nottingham North & Kimberley',
#        'Nottingham South', 'Nuneaton', 'Old Bexley & Sidcup',
#        'Oldham East & Saddleworth', 'Oldham W Chadderton & Royton',
#        'Orkney & Shetland', 'Orpington', 'Ossett & Denby Dale',
#        'Oxford East', 'Oxford West & Abingdon',
#        'Paisley & Renfrewshire North', 'Paisley & Renfrewshire South',
#        'Peckham', 'Pembrokeshire Mid & South', 'Pendle & Clitheroe',
#        'Penistone & Stocksbridge', 'Penrith & Solway',
#        'Perth & Kinross-shire', 'Peterborough', 'Plymouth Moor View',
#        'Plymouth Sutton & Devonport', "Pontefract, C'ford & Knot.",
#        'Pontypridd', 'Poole', 'Poplar & Limehouse', 'Portsmouth North',
#        'Portsmouth South', 'Preston', 'Putney',
#        "Queen's Park & Maida Vale", 'Rawmarsh & Conisbrough',
#        'Rayleigh & Wickford', 'Reading Central',
#        'Reading West & Mid Berkshire', 'Redcar', 'Redditch', 'Reigate',
#        'Renfrewshire East', 'Rhondda & Ogmore', 'Ribble Valley',
#        'Richmond & Northallerton', 'Richmond Park', 'Rochdale',
#        'Rochester & Strood', 'Romford', 'Romsey & Southampton North',
#        'Rossendale & Darwen', 'Rother Valley', 'Rotherham', 'Rugby',
#        'Ruislip, Northwood & Pinner', 'Runcorn & Helsby',
#        'Runnymede & Weybridge', 'Rushcliffe', 'Rutherglen',
#        'Rutland & Stamford', 'Salford', 'Salisbury',
#        'Scarborough & Whitby', 'Scunthorpe', 'Sefton Central', 'Selby',
#        'Sevenoaks', 'Sheffield Brightside', 'Sheffield Central',
#        'Sheffield Hallam', 'Sheffield Heeley', 'Sheffield South East',
#        'Sherwood Forest', 'Shipley', 'Shrewsbury', 'Shropshire North',
#        'Shropshire South', 'Sittingbourne & Sheppey', 'Skipton & Ripon',
#        'Sleaford & North Hykeham', 'Slough', 'Smethwick',
#        'Solihull West & Shirley', 'Somerset North',
#        'Somerset North East & Hanham', 'South Down',
#        'South Holland and The Deepings', 'South Ribble', 'South Shields',
#        'Southampton Itchen', 'Southampton Test',
#        'Southend East & Rochford', 'Southend West & Leigh',
#        'Southgate & Wood Green', 'Southport', 'Spelthorne', 'Spen Valley',
#        'St Albans', 'St Austell & Newquay', 'St Helens North',
#        'St Helens South & Whiston', 'St Ives', 'St Neots & Mid Cambs',
#        'Stafford', 'Staffordshire Moorlands', 'Stalybridge & Hyde',
#        'Stevenage', 'Stirling & Strathallan', 'Stockport',
#        'Stockton North', 'Stockton West', 'Stoke-on-Trent Central',
#        'Stoke-on-Trent North', 'Stoke-on-Trent South',
#        'Stone, Gt Wyrley & Penkridge', 'Stourbridge', 'Strangford',
#        'Stratford & Bow', 'Stratford-on-Avon',
#        'Streatham & Croydon North', 'Stretford & Urmston', 'Stroud',
#        'Suffolk Central & N Ipswich', 'Suffolk Coastal', 'Suffolk South',
#        'Suffolk West', 'Sunderland Central', 'Surrey East',
#        'Surrey Heath', 'Sussex Mid', 'Sussex Weald', 'Sutton & Cheam',
#        'Sutton Coldfield', 'Swansea West', 'Swindon North',
#        'Swindon South', 'Tamworth', 'Tatton', 'Taunton & Wellington',
#        'Telford', 'Tewkesbury', 'Thanet East', 'Thirsk & Malton',
#        'Thornbury & Yate', 'Thurrock', 'Tipton & Wednesbury',
#        'Tiverton & Minehead', 'Tonbridge', 'Tooting', 'Torbay', 'Torfaen',
#        'Torridge & Tavistock', 'Tottenham', 'Truro & Falmouth',
#        'Tunbridge Wells', 'Twickenham', 'Tynemouth', 'Tyrone West',
#        'Ulster Mid', 'Upper Bann', 'Uxbridge & South Ruislip',
#        'Vale of Glamorgan', 'Vauxhall & Camberwell Green',
#        'Wakefield & Rothwell', 'Wallasey', 'Walsall & Bloxwich',
#        'Walthamstow', 'Warrington North', 'Warrington South',
#        'Warwick & Leamington', 'Warwickshire N & Bedworth',
#        'Washington & Gateshead South', 'Watford', 'Waveney Valley',
#        'Weald of Kent', 'Wellingborough & Rushden',
#        'Wells & Mendip Hills', 'Welwyn Hatfield', 'West Bromwich',
#        'West Ham & Beckton', 'Westmorland & Lonsdale',
#        'Weston-super-Mare', 'Wetherby & Easingwold',
#        'Whitehaven & Workington', 'Widnes & Halewood', 'Wigan',
#        'Wiltshire East', 'Wiltshire South West', 'Wimbledon',
#        'Winchester', 'Windsor', 'Wirral West', 'Witham', 'Witney',
#        'Woking', 'Wokingham', 'Wolverhampton North East',
#        'Wolverhampton South East', 'Wolverhampton West', 'Worcester',
#        'Worcestershire West', 'Worsley & Eccles',
#        'Worthing East & Shoreham', 'Worthing West', 'The Wrekin',
#        'Wrexham', 'Wycombe', 'Wyre Forest', 'Wythenshawe & Sale East',
#        'Yeovil', 'Ynys Mon', 'York Central', 'York Outer'], dtype=object)

# %%
df['constituency'].nunique()
# Out:
# 650

# %%
df.sample(5)
# Out:
#       voteCount  votePercentage  votePercentageChange candidate_firstName  \
# 2507       3826        9.145015              5.808735             Sharmen
# 1193       2151        4.557493              2.662920              Te Ata
# 3068       1336        3.816380              0.063795               David
# 1934       1036        2.829132             -2.094683                John
# 3847        650        1.519757              1.519757           Alexander
#
#      candidate_surname party_abbreviation               party_name  \
# 2507            Rahman              Green                    Green
# 1193            Browne              Green                    Green
# 3068           Schmitz                 LD         Liberal Democrat
# 1934            Lawson                 LD         Liberal Democrat
# 3847           Bramham            Soc Dem  Social Democratic Party
#
#      party_displayName                  constituency  Electorate_size  \
# 2507             Green               Leicester South            70867
# 1193             Green              Crewe & Nantwich            78423
# 3068           Lib Dem  Nottingham North & Kimberley            73768
# 1934           Lib Dem   Great Grimsby & Cleethorpes            77050
# 3847               SDP  Stone, Gt Wyrley & Penkridge            69378
#
#       Turnout_perc     new_party     old_party
# 2507     59.035941   Independent        Labour
# 1193     60.182599        Labour  Conservative
# 3068     47.455536        Labour        Labour
# 1934     47.526282        Labour  Conservative
# 3847     61.647785  Conservative  Conservative
